# %% [markdown]
# wildE VRT (nativ)
#     → [woody_metrics_wip] gdal.Warp → woody_cover_500m_3035.tif
#                                               │
# GEE MCD64A1                                   │
#     → [01_mba_yearly] → MBA_mosaic.tif ───────┤
#                                               ▼
#                                 [02_combine_woody_fire] → woody_burned_MBA_full_combined.tif
#                                                                       │
#                               GEE MCD12Q1 ─────────────────────────►─┤
#                               EEA Shapefile → [04_ecoregions] ───────►┤
#                                                                       ▼
#                                                         [05_landcover_analysis] → Plots/CSVs
#                                                                       │
#                                                                       ▼
#                                                         [06_trajectory_clustering]
